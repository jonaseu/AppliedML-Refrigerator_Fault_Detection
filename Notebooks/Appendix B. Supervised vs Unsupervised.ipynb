# %% [markdown]
# # Appendix B. Supervised vs Unsupervised
#
# ## 1. Summary
#
# Objective of this notebook is the present the basic overview of what is a supervised machine learning task vs an unsupervised machine learning task, and then discuss how those two different approaches relate to our problem at hand of fault classification.
#
# ![image.png](attachment:image-2.png)
#
# ### 1.1 Why this matter?
# Understanding the difference between those two different approaches is important because deciding which approach to go with can drastically change what are the main actions that Whirlpool needs to work on to effectively build a machine learning pipeline.
#
# ### 1.2 Key Takeaways
# - The main distinction between the two approaches is the use of labeled datasets. To put it simply, supervised learning uses labeled input and output data, while an unsupervised learning algorithm does not.
# - For Whirlpool the best approach for the future is to go with Supervised methods, since the main goal that we try to achieve is **classify faults that are known** and Whirlpool has the potential and knowledge to manually detect and label those datasets
# - Anyway, there is still the potential to use Unsupervised methods to try to detect anomaly data
#
#
# ### 1.2 Reference
# This material is a summary of:
# - [Supervised vs. Unsupervised Learning: What’s the Difference?](https://www.ibm.com/cloud/blog/supervised-vs-unsupervised-learning)
# - [Andrew NG AI Lectures - 13.1](https://www.youtube.com/watch?v=Ev8YbxPu_bQ)

# %% [markdown]
# ***
# ## 2. Supervised
#
# Uses a labeled datasets, that are designed to train or “supervise” algorithms into classifying data or predicting outcomes accurately. Using labeled inputs and outputs, the model can measure its accuracy.
#
# Typical examples of that are:
# - Classification: traning dataset indicates that this input is CLASS X, so my model should output CLASS X
# - Regression algorithms: training dataset indicates that this input is around X, so my model should output as close as possible to X

# %% [markdown]
# ***
# ## 3. Unsupervised
#
# Analyzes and clusters unlabeled data sets, by **discovering hidden patterns** in data without the need for human intervention (hence, they are “unsupervised”).
#
# Typical examples of that are:
# - Clustering - This input is similar to another one, so they probably should be grouped (K-means algorithm for example)
# - Association - This input is alway bought with this one, so they probably should be grouped
# - Dimensionality Reduction - This variable is too similar to this other one, so they don't add value to models, so it can probably be removed (PCA algorithm for example)

# %% [markdown]
# ***
# ## 4. Supervised vs Unsupervised for Whirlpool
#
# In **supervised** learning, the algorithm “learns” from the training dataset by iteratively making predictions on the data and adjusting for the correct answer. While supervised learning models tend to be more accurate than unsupervised learning models, they require upfront **human intervention to label the data appropriately**.
#
# **Unsupervised** learning models, in contrast, work on **their own to discover the inherent structure of unlabeled data**. Note that they still require some human intervention for validating output variables.
#
# Supervised goal is to predict by knowing upfront what to expect. Unsupervised is to get insights from the data, the model will decide what is different on the dataset
#
#
# ### 5.1 Which approach should Whirlpool Use?
#
# Of course there is no hard rule, we can choose any of the approaches and make different trials from time to time, and as well as use a mix of the approaches. But as a rule of thumb, the main things we need to reflect on are:
#
# - Evaluate your input data: Is it labeled or unlabeled data? Do you have experts that can support additional labeling?
#     Today most of our refrigeration data is unlabeled (we never know if they are faulty or not faulty products), and in most cases there is not even data about faults, and also sometimes we have data that are from bad products that were being tested. But yes, we certainly do have experts and people who could manually label those data.
#
# - Define your goals: Do you have a recurring, well-defined problem to solve? Or will the algorithm need to predict new problems?
#     Yes, we have problems that are clear and recurring: faulty compressors, faulty dampers, faulty fans and so on, and overall they behave similarly.
